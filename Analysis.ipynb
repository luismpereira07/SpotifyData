# %%
import numpy as np
import pandas as pd

df = pd.read_csv('data.csv')
df.head()
df = df.drop(columns=['key'])

correlation_df = df.corr()
print(correlation_df)
#df.to_csv(r'C:\Users\lmartins\Downloads\Spotify\correlatio_data.csv', index = False, header=True)

#import matplotlib.pyplot as plt
#plt.pcolor(correlation_df)
#plt.yticks(np.arange(0.5, len(correlation_df.index), 1), correlation_df.index)
#plt.xticks(np.arange(0.5, len(correlation_df.columns), 1), correlation_df.columns)
#plt.show()

import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 9))

sns.heatmap(correlation_df, annot=True)
# Out:
#                    valence      year  acousticness  danceability  duration_ms  \
# valence           1.000000 -0.028245     -0.184101      0.558946    -0.191813
# year             -0.028245  1.000000     -0.614250      0.188515     0.079713
# acousticness     -0.184101 -0.614250      1.000000     -0.266852    -0.076373
# danceability      0.558946  0.188515     -0.266852      1.000000    -0.139937
# duration_ms      -0.191813  0.079713     -0.076373     -0.139937     1.000000
# energy            0.353876  0.530272     -0.749393      0.221967     0.042119
# explicit         -0.018613  0.220881     -0.246007      0.241757    -0.048880
# instrumentalness -0.198501 -0.272371      0.329819     -0.278063     0.084770
# liveness          0.003832 -0.057318     -0.024482     -0.100193     0.047168
# loudness          0.313512  0.487697     -0.561696      0.285057    -0.003037
# mode              0.015641 -0.032385      0.047168     -0.045956    -0.046085
# ...

# %%
import numpy as np
import pandas as pd

dfg = pd.read_csv('data.csv')
dfg.head()
dfg = dfg.drop(columns=['key','acousticness','danceability','duration_ms','energy','instrumentalness','liveness','loudness','speechiness','tempo','valence','mode','release_date','id','explicit','year'])

dfg_zimmer = dfg[dfg['artists']=="['Hans Zimmer']"]
df_gor  = dfg[dfg['artists']=="['Gorillaz']"]
df_M83  = dfg[dfg['artists']=="['M83']"]
df_imon = dfg[dfg['artists']=="['I Monster']"]
df_le = dfg[dfg['artists']=="['Ludovico Einaudi']"]
df_pg = dfg[dfg['artists']=="['Philip Glass']"]
df_as = dfg[dfg['artists']=="['Alan Silvestri']"]
df_dp = dfg[dfg['artists']=="['Daft Punk']"]

df_cc = dfg[dfg['artists']=="['Camila Cabello']"]
dfg_swift = dfg[dfg['artists']=="['Taylor Swift']"]
df_ellish  = dfg[dfg['artists']=="['Billie Eilish']"]
df_lamar  = dfg[dfg['artists']=="['Kendrick Lamar']"]
df_grande  = dfg[dfg['artists']=="['Ariana Grande']"]
df_weeknd  = dfg[dfg['artists']=="['The Weeknd']"]
df_drake  = dfg[dfg['artists']=="['Drake']"]

#df = df_pg.append(dfg_zimmer).append(df_le).append(df_as).append(df_imon).append(df_gor).append(df_M83).append(df_dp).append(df_lamar).append(df_cc).append(dfg_swift).append(df_grande).append(df_drake).append(df_weeknd).append(df_ellish)
df = df_pg.append([dfg_zimmer,df_le,df_as,df_imon,df_gor,df_M83,df_dp,df_lamar,df_cc,dfg_swift,df_drake,df_weeknd,df_grande,df_ellish])

#boxplot = df.boxplot(by='valence')

#import seaborn as sns
#sns.set_theme(style="whitegrid")
#tips = sns.load_dataset("tips")
#ax = sns.boxplot(x='genres', y='energy', data=tips)

import seaborn as sns
#sns.set_theme(style='whitegrid')
#genres = sns.load_dataset(dfg)
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 9))
ax = sns.boxplot(data=df, palette="Set2", orient="h", x="popularity", y="artists")

#import seaborn as sns
#sns.set_theme(style="whitegrid")
#import matplotlib.pyplot as plt
#plt.figure(figsize=(12, 9))
#ax = sns.violinplot(data=df, palette="Set2", orient="h", x="popularity", y="artists")

# %%
import numpy as np
import pandas as pd

dfg = pd.read_csv('data.csv')
dfg.head()
dfg['popularity'] = dfg['popularity']/100
#dfg = dfg.drop(columns=['key','acousticness','danceability','duration_ms','energy','instrumentalness','liveness','loudness','speechiness','tempo','valence','mode','release_date','id','explicit','year'])

dfg_zimmer = dfg[dfg['artists'].str.contains("Hans Zimmer")]
dfg_zimmer['artists'] = 'Hans Zimmer'

df_gor = dfg[dfg['artists'].str.contains("Gorillaz")]
df_gor['artists'] = 'Gorillaz'

df_M83 = dfg[dfg['artists'].str.contains("M83")]
df_M83['artists'] = 'M83'

df_imon = dfg[dfg['artists'].str.contains("I Monster")]
df_imon['artists'] = 'I Monster'

df_le = dfg[dfg['artists'].str.contains("Ludovico Einaudi")]
df_le['artists'] = 'Ludovico Einaudi'

df_pg =  dfg[dfg['artists'].str.contains("Philip Glass")]
df_pg['artists'] = 'Philip Glass'

df_as =  dfg[dfg['artists'].str.contains("Alan Silvestri")]
df_as['artists'] = 'Alan Silvestri'

df_dp =  dfg[dfg['artists'].str.contains("Daft Punk")]
df_dp['artists'] = 'Daft Punk'

df_vi =  dfg[dfg['artists'].str.contains("Vivaldi")]
df_vi['artists'] = 'Vivaldi'

df_jh =  dfg[dfg['artists'].str.contains("John Williams")]
df_jh['artists'] = 'John Williams'

df_rw =  dfg[dfg['artists'].str.contains("Richard Wagner")]
df_rw['artists'] = 'Richard Wagner'

df_st =  dfg[dfg['artists'].str.contains("Ludwig van Beethoven")]
df_st['artists'] = 'Ludwig van Beethoven'

df_mr =  dfg[dfg['artists'].str.contains("Ravel")]
df_mr['artists'] = 'Ravel'

df_bc =  dfg[dfg['artists'].str.contains("Bill Conti")]
df_bc['artists'] = 'Bill Conti'

########################3

df_bs =  dfg[dfg['artists'].str.contains("Black Sabbath")]
df_bs['artists'] = 'Black Sabbath'

df_adele =  dfg[dfg['artists'].str.contains("Adele")]
df_adele['artists'] = 'Adele'

df_spkn =  dfg[dfg['artists'].str.contains("Slipknot")]
df_spkn['artists'] = 'Slipknot'

df_cc =  dfg[dfg['artists'].str.contains("Camila Cabello")]
df_cc['artists'] = 'Camila Cabello'

dfg_swift =  dfg[dfg['artists'].str.contains("Taylor Swift")]
dfg_swift['artists'] = 'Taylor Swift'

df_ellish =  dfg[dfg['artists'].str.contains("Billie Eilish")]
df_ellish['artists'] = 'Billie Eilish'

df_lamar =  dfg[dfg['artists'].str.contains("Kendrick Lamar")]
df_lamar['artists'] = 'Kendrick Lamar'

df_grande =  dfg[dfg['artists'].str.contains("Ariana Grande")]
df_grande['artists'] = 'Ariana Grande'

df_weeknd =  dfg[dfg['artists'].str.contains("The Weeknd")]
df_weeknd['artists'] = 'The Weeknd'

df_gaga =  dfg[dfg['artists'].str.contains("Lady Gaga")]
df_gaga['artists'] = 'Lady Gaga'

df_bts =  dfg[dfg['artists'].str.contains("BTS")]
df_bts['artists'] = 'BTS'


df = df_pg.append([df_mr,df_as,df_jh,df_st,dfg_zimmer,df_bc,df_M83,df_adele,df_imon,df_bs,df_spkn,df_gor,df_weeknd,df_cc,df_grande,df_bts,df_ellish])

import seaborn as sns
#sns.set_theme(style='whitegrid')
#genres = sns.load_dataset(dfg)
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 9))
#ax = sns.boxplot(data=df, palette="Set2", orient="h", x="popularity", y="artists")
#ax = sns.boxplot(data=df, palette="Set2", orient="h", x="instrumentalness", y="artists")
ax = sns.boxplot(data=df, color=".15", orient="h", x="popularity", y="artists") #black
#plt.savefig('plot.png')
ax = sns.boxplot(data=df, color=".90", orient="h", x="instrumentalness", y="artists")  #white

plt.savefig('plot-artistss.png')
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# ...

# %%
import numpy as np
import pandas as pd

df2 = pd.read_csv('data_by_genres.csv')
#df2 = df2.drop(columns=['key','acousticness','danceability','duration_ms','energy','instrumentalness','liveness','loudness','speechiness','tempo','valence','mode'])
df2['popularity'] = df2['popularity']/100
df2.head()

df_soundtrack =  df2[df2['genres'].str.contains("soundtrack")]
df_soundtrack['genres'] = 'soundtrack'
df_score =  df2[df2['genres'].str.contains("score")]
df_score['genres'] = 'soundtrack'
df_score2 =  df2[df2['genres'].str.contains("score")]
df_score2['genres'] = 'soundtrack'
df_score3 =  df2[df2['genres'].str.contains("epicore")]
df_score3['genres'] = 'soundtrack'
df_soundtrack = df_soundtrack.append([df_score,df_score2,df_score3])
#df_soundtrack.loc[0]
#df2_soundtrack =  df2[df2['genres'].str.contains("instrumental")]

df_triphop =  df2[df2['genres'].str.contains("nu jazz")]
df_triphop2 =  df2[df2['genres'].str.contains("trip hop")]
df_triphop3 =  df2[df2['genres'].str.contains("downtempo")]
df_triphop4 =  df2[df2['genres'].str.contains("alternative hip hop")]
df_triphop5 =  df2[df2['genres'].str.contains("french shoegaze")]
df_triphop6 =  df2[df2['genres'].str.contains("ninja")]
df_triphop7 =  df2[df2['genres'].str.contains("bigbeat")]
df_triphop8 =  df2[df2['genres'].str.contains("indietronica")]
df_triphop9 =  df2[df2['genres'].str.contains("alternative dance")]
df_triphop10 =  df2[df2['genres'].str.contains("synthpop")]

df_triphop = df_triphop.append([df_triphop2],[df_triphop3],[df_triphop4],[df_triphop5])
df_triphop = df_triphop.append([df_triphop6],[df_triphop7],[df_triphop8],[df_triphop9])
#df_triphop = df_triphop.append([df_triphop10])
df_triphop['genres'] = 'Trip Hop'
df_triphop.loc[0]

df_classical =  df2[df2['genres'].str.contains("classical")]
df_classical['genres'] = 'Classical'
df_classical2 =  df2[df2['genres'].str.contains("Orchestra")]
df_classical2['genres'] = 'Classical'
df_classical = df_classical.append([df_classical2])
#df2_class = df2[df2['genres'].str.contains("instrumental")]

df_pop =  df2[df2['genres'].str.contains("electropop")]
df_pop['genres'] = 'Pop'
df2_pop =  df2[df2['genres'].str.contains("pop")]

df_rock =  df2[df2['genres'].str.contains("metal")]
df_rock['genres'] = 'Heavy Metal'

df_sw =  df2[df2['genres'].str.contains("afro")]
df_sw['genres'] = 'Afro'

df_house =  df2[df2['genres'].str.contains("house")]
df_house['genres'] = 'House'
df2_house = df2[df2['genres'].str.contains("house")]

df_e =  df2[df2['genres'].str.contains("electronic")]
df_e['genres'] = 'Electronica'

df_i =  df2[df2['genres'].str.contains("indie")]
df_i['genres'] = 'Indie'

df_b =  df2[df2['genres'].str.contains("blues")]
df_b['genres'] = 'Blues'

df_j =  df2[df2['genres'].str.contains("jazz")]
df_j['genres'] = 'Jazz'

df_d =  df2[df2['genres'].str.contains("disco")]
df_d['genres'] = 'Disco'

df_r =  df2[df2['genres'].str.contains("rock")]
df_r['genres'] = 'Rock'

df_hh =  df2[df2['genres'].str.contains("hip hop")]
df_hh['genres'] = 'Hip Hop'
df_hh2 =  df2[df2['genres'].str.contains("rap")]
df_hh2['genres'] = 'Hip Hop'
df_hh = df_hh.append([df_hh2])

df3 = df_classical.append([df_soundtrack,df_triphop,df_house,df_rock,df_pop,df_r,df_i,df_hh])
import seaborn as sns
#sns.set_theme(style='whitegrid')
#genres = sns.load_dataset(dfg)
import matplotlib.pyplot as plt
plt.figure(figsize=(18, 9))
ax = sns.boxplot(data=df3, color=".15", orient="h", x="popularity", y="genres") #black
ax = sns.boxplot(data=df3, color=".90", orient="h", x="instrumentalness", y="genres")  #white
plt.savefig('plot-artist.png')

#ax2 = sns.boxplot(data=df2_soundtrack, palette="Set2", orient="h", x="popularity", y="genres")
#ax3 = sns.boxplot(data=df2_house, palette="Set2", orient="h", x="popularity", y="genres")
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# ...

# %%
#import seaborn as sns
#sns.set_theme(style='whitegrid')
#genres = sns.load_dataset(dfg)
#import matplotlib.pyplot as plt
#plt.figure(figsize=(18, 9))
#ax = sns.boxplot(data=df3, color=".15", orient="h", x="popularity", y="genres") #black
#ax = sns.boxplot(data=df3, color=".90", orient="h", x="instrumentalness", y="genres")  #white
#plt.savefig('plot-artist.png')

import seaborn as sns
#sns.set_theme(style="white")

# Plot miles per gallon against horsepower with other semantics
sns.relplot(x="valence", y="energy", hue="genres", size="duration_ms",
            sizes=(40, 400), alpha=.5, palette="muted",
            height=6, data=df3)

sns.relplot(x="valence", y="energy", size="popularity",
            sizes=(40, 400), alpha=.5, palette="muted",
            height=6, data=df_gor)

# %%
import numpy as np
import pandas as pd
import json

d1 = open('StreamingHistory0.json')
d2 = open('StreamingHistory1.json')
d3 = open('StreamingHistory2.json')

df = df.to_json(orient='table')

#dfmy = d1.appends([d2,d3])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-77bcfd4efde0> in <module>
#       7 d3 = open('StreamingHistory2.json')
#       8
# ----> 9 df = df.to_json(orient='table')
#      10
#      11 #dfmy = d1.appends([d2,d3])
#
# AttributeError: 'str' object has no attribute 'to_json'

# %%
import numpy as np
import pandas as pd

dfg = pd.read_csv('data.csv')
dfg.head()
#dfg = dfg.drop(columns=['key','acousticness','danceability','duration_ms','energy','instrumentalness','liveness','loudness','speechiness','tempo','valence','mode','release_date','id','explicit','year'])
dfg = dfg.drop(columns=['key','tempo','mode','release_date','id','explicit','year'])

df_st =  dfg[dfg['artists'].str.contains("Taylor Swift")]
df_st = df_st.sort_values(by=['popularity'], ascending=False)
df_st.head(20)
# Out:
#        valence  acousticness  \
# 19726   0.5510       0.53700
# 19782   0.1520       0.77800
# 19793   0.1720       0.75700
# 19581   0.7280       0.03300
# 19511   0.7140       0.00929
# 19566   0.6330       0.07670
# 19564   0.4530       0.49200
# 17340   0.3060       0.13100
# 37874   0.1060       0.05860
# 18114   0.6790       0.00454
# 57210   0.4030       0.53800
# 19130   0.0499       0.21600
# 18115   0.7500       0.00957
# 37821   0.5060       0.20400
# 57333   0.1110       0.80600
# 57276   0.7060       0.46700
# 57264   0.4500       0.83800
# 57216   0.5020       0.60000
# 57091   0.4220       0.43300
# 38325   0.5640       0.11700
#
#                                                  artists  danceability  \
# 19726                                   ['Taylor Swift']         0.613
# 19782                       ['Taylor Swift', 'Bon Iver']         0.298
# 19793                                   ['Taylor Swift']         0.777
# ...
